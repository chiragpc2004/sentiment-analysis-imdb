# %% [markdown]
# # **Sentiment Analysis on [IMDB Dataset of 50K Movie Reviews](https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews/data)**

# %% [markdown]
# ## 🚀 **Let's Connect!**
# <p align="left">
#   <a href="https://github.com/chiragpc2004" target="_blank">
#     <img src="https://img.shields.io/badge/GitHub-%23181717.svg?&style=for-the-badge&logo=github&logoColor=white" alt="GitHub"/>
#   </a>
#   <a href="https://www.linkedin.com/in/chiragpc2004/" target="_blank">
#     <img src="https://img.shields.io/badge/LinkedIn-0077B5?style=for-the-badge&logo=linkedin&logoColor=white" alt="LinkedIn"/>
#   </a>
#   <a href="https://mail.google.com/mail/?view=cm&fs=1&to=chiragpc2004@gmail.com" target="_blank">
#     <img src="https://img.shields.io/badge/Gmail-%23D14836.svg?&style=for-the-badge&logo=gmail&logoColor=white" alt="Gmail"/>
#   </a>
# </p>

# %% [markdown]
# ## **Loading the IMDB 50K Movie Reviews Dataset and Performing Basic Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Exploratory Data Analysis**
#
# - Understand the **structure of the dataset** including rows, columns, and data types.
# - Gain **basic insights** using `describe()` and `info()` to summarize the data.
# - Analyze the **count of unique values**, check for **duplicates**, and identify any **missing values**.
# - Explore the **number of words and characters** in each review to understand the text length distribution.
# - Perform **basic exploratory analysis** to uncover patterns or anomalies in the dataset.

# %% [markdown]
# #### Import statements

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the dataset
df = pd.read_csv("D:/imdb-sentiment-classifier/data/raw/IMDB_Dataset.csv")
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
# Some basic information
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB
# None

# %%
# Some insights on the data
df.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
# Number of distinct values in sentiment column
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
# Number of distinct reviews
print("Total number of distinct reviews: ",df['review'].value_counts().count())
# Out:
# Total number of distinct reviews:  49582

# %%
# Check for duplicates
print("Total number of duplicated reviews:", df.duplicated().sum())
# Out:
# Total number of duplicated reviews: 418

# %%
# Sentiment bar plot
sns.countplot(x='sentiment', data=df)
plt.title("Distribution of Sentiment Labels")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
# Distribution of review lengths
review_lengths = df['review'].apply(lambda x: len(x.split()))
plt.hist(review_lengths, bins=50, color='salmon')
plt.title('Distribution of Review Lengths')
plt.xlabel('Number of Words')
plt.ylabel('Number of Reviews')
plt.show()

# %%
# Boxplot of Review Length by sentiment
df['review_length'] = df['review'].apply(lambda x: len(x.split()))
sns.boxplot(x='sentiment', y='review_length', data=df)
plt.title('Review Length by Sentiment')
plt.xlabel('Sentiment (0 = Negative, 1 = Positive)')
plt.ylabel('Review Length (Words)')
plt.show()

# %%
# Review length stats
df['char_length'] = df['review'].str.len()
df['word_count'] = df['review'].str.split().str.len()
print("\nCharacter length stats:\n", df['char_length'].describe())
print("\nWord count stats:\n", df['word_count'].describe())
# Out:
# Character length stats:
#  count    50000.000000
# mean      1309.431020
# std        989.728014
# min         32.000000
# 25%        699.000000
# 50%        970.000000
# 75%       1590.250000
# max      13704.000000
# Name: char_length, dtype: float64
#
# Word count stats:
#  count    50000.000000
# mean       231.156940
# std        171.343997
# min          4.000000
# 25%        126.000000
# 50%        173.000000
# 75%        280.000000
# max       2470.000000
# Name: word_count, dtype: float64
